# %% [markdown]
# # FACIAL EXPRESSIONS DETECTION PROJECT
#
# - The data consists of **48x48** pixel grayscale images of faces. The faces have been automatically registered so that the face is more or less centred and occupies about the same amount of space in each image.
#
# The _task_ is to categorize each face based on the emotion shown in the facial expression into one of seven categories:
#
# 0) **Angry**
#
# 1) **Disgust**
#
# 2) **Fear**
#
# 3) **Happy**
#
# 4) **Neutral**
#
# 5) **Sad**
#
# 6) **Surprise**

# %% [markdown]
# # Libraries

# %%
import os
os.environ['KAGGLE_USERNAME'] = "hassanalzayer"
os.environ['KAGGLE_KEY'] = "7fd2639f02f6393ffdc26a4ea6186e20"
import random
import shutil

# %%
import numpy as np
import cv2 as cv
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import keras as kr

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Dense,Dropout,BatchNormalization,Flatten,AveragePooling2D
from tensorflow.keras.optimizers import Adam,RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.utils import np_utils

# %%
from IPython.display import HTML
import matplotlib.animation as animation

# %% [markdown]
# # Class Parameters

# %%
class RESULTS:
    pass
class PARAMETERS:
    pass
class CLASSINIT:
    pass

# %% [markdown]
# # Data Path Process

# %%
train_path = "/content/train"
test_path = "/content/test"

# %%
name_list = ["ANGRY","DISGUST","FEAR","HAPPY","NEUTRAL","SAD","SURPRISE"]

# %%
angry = []
disgust = []
fear = []
happy = []
neutral = []
sad = []
surprise = []

# %%
data_list = []

# %%
for r,d,f in os.walk(train_path,topdown=False):
    if "angry" in r:
        for x_name in f:
            angry.append(os.path.join(r,x_name))
            data_list.append((os.path.join(r,x_name),0))
    elif "disgust" in r:
        for x_name in f:
            disgust.append(os.path.join(r,x_name))
            data_list.append((os.path.join(r,x_name),1))
    elif "fear" in r:
        for x_name in f:
            fear.append(os.path.join(r,x_name))
            data_list.append((os.path.join(r,x_name),2))
    elif "happy" in r:
        for x_name in f:
            happy.append(os.path.join(r,x_name))
            data_list.append((os.path.join(r,x_name),3))
    elif "neutral" in r:
        for x_name in f:
            neutral.append(os.path.join(r,x_name))
            data_list.append((os.path.join(r,x_name),4))
    elif "sad" in r:
        for x_name in f:
            sad.append(os.path.join(r,x_name))
            data_list.append((os.path.join(r,x_name),5))
    elif "surprise" in r:
        for x_name in f:
            surprise.append(os.path.join(r,x_name))
            data_list.append((os.path.join(r,x_name),6))
    else:
        pass

print("[+] DONE - SUCCESS")
# Out:
# [+] DONE - SUCCESS

# %%
full_list = [angry,disgust,fear,happy,neutral,sad,surprise]

# %%
for x_n,x_l in zip(name_list,full_list):
    print(f"LEN OF {x_n} FILE: {len(x_l)}")
# Out:
# LEN OF ANGRY FILE: 3995
# LEN OF DISGUST FILE: 436
# LEN OF FEAR FILE: 4097
# LEN OF HAPPY FILE: 7215
# LEN OF NEUTRAL FILE: 4965
# LEN OF SAD FILE: 4830
# LEN OF SURPRISE FILE: 3171

# %%
print(f"TOTAL DATA LEN: {len(data_list)}")
# Out:
# TOTAL DATA LEN: 28709

# %%
random.shuffle(data_list)

# %%
path_all = []
class_all = []
for x_cnt in range(len(data_list)):
    path_all.append(data_list[x_cnt][0])
    class_all.append(data_list[x_cnt][1])

# %%
pt_series = pd.Series(path_all,name="PATH")
cl_series = pd.Series(class_all,name="CLASS")

# %%
dataframe = pd.concat([pt_series,cl_series],axis=1)

# %%
print(f"UNIQUE TARGETS: {np.unique(dataframe.CLASS.values)}")
# Out:
# UNIQUE TARGETS: [0 1 2 3 4 5 6]

# %% [markdown]
# # Image and Parameter Control

# %%
def single_visual(pt:str,cl:str or int)->RESULTS:
    img = cv.cvtColor(cv.imread(pt),cv.COLOR_BGR2RGB)
    plt.figure(figsize=(15,8))
    plt.xlabel(f"SHAPE: {img.shape}")
    plt.ylabel(f"SIZE: {img.size}")
    plt.title(f"CONTROL CLASS: {cl}")
    plt.imshow(img)
    plt.tight_layout()
    plt.show()

# %%
if dataframe.empty:
    print("DataFrame is empty. Add data before accessing values.")
else:
    single_visual(dataframe.PATH[0],dataframe.CLASS[0])
    single_visual(dataframe.PATH[10000],dataframe.CLASS[10000])

# %%
plt.figure(figsize=(15,25))
i_c = 1
for x_path in range(len(dataframe.PATH.values)):
    plt.subplot(1,7,i_c)
    img = cv.cvtColor(cv.imread(dataframe.PATH[x_path*50]),cv.COLOR_BGR2RGB)
    plt.axis("off")
    plt.title(f"CONTROL CLASS: {dataframe.CLASS[x_path*50]}")
    plt.imshow(img)
    if i_c == 7:
        break
    i_c += 1
plt.tight_layout()
plt.show()

# %% [markdown]
# # Before Training

# %%
def convert_process(lm:list,ls:list,dt:classmethod,pr:str,tr:str)->RESULTS:
    for x_path in range(len(dt[pr].values)):
        img = cv.cvtColor(cv.imread(dt[pr][x_path]),cv.COLOR_BGR2GRAY)
        trg = dt[tr][x_path]
        img = img.reshape(img.shape[0],img.shape[1])
        img = img / 255.
        lm.append(img)
        ls.append(trg)

# %%
data_image = []
target_image = []
convert_process(data_image,target_image,dataframe,"PATH","CLASS")

# %%
print(f"TOTAL LEN OF DATA: {len(data_image)}")
print(f"TOTAL LEN OF TARGET CLASS: {len(target_image)}")
# Out:
# TOTAL LEN OF DATA: 28709
# TOTAL LEN OF TARGET CLASS: 28709

# %%
data_array = np.array(data_image)
target_array = np.array(target_image)

# %%
print(f"DATA SHAPE: {data_array.shape}")
print(f"TARGET SHAPE: {target_array.shape}")
# Out:
# DATA SHAPE: (28709, 48, 48)
# TARGET SHAPE: (28709,)

# %%
val_data = data_array[data_array.shape[0]-2000:,:,:]
val_target = target_array[target_array.shape[0]-2000:]

# %%
data_array = data_array[0:data_array.shape[0]-2000,:,:]
target_array = target_array[0:target_array.shape[0]-2000]

# %%
print(f"VALIDATE DATA SHAPE: {val_data.shape}")
print(f"VALIDATE TARGET SHAPE: {val_target.shape}")
# Out:
# VALIDATE DATA SHAPE: (2000, 48, 48)
# VALIDATE TARGET SHAPE: (2000,)

# %%
print(f"LAST DATA SHAPE: {data_array.shape}")
print(f"LAST TARGET SHAPE: {target_array.shape}")
# Out:
# LAST DATA SHAPE: (26709, 48, 48)
# LAST TARGET SHAPE: (26709,)

# %%
plt.figure(figsize=(15,8))
plt.xlabel(f"SHAPE: {data_array[25000].shape}")
plt.ylabel(f"SIZE: {data_array[25000].size}")
plt.title(f"CONTROL CLASS: {target_array[25000]}")
plt.imshow(data_array[25000])
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.xlabel(f"SHAPE: {data_array[12000].shape}")
plt.ylabel(f"SIZE: {data_array[12000].size}")
plt.title(f"CONTROL CLASS: {target_array[12000]}")
plt.imshow(data_array[12000])
plt.tight_layout()
plt.show()

# %%
mpath = "modelcheckpoint"
if os.path.exists(mpath):
    pass
else:
    os.mkdir(mpath)

# %%
#early = tf.keras.callbacks.EarlyStopping(monitor="val_loss",
                                        #patience=7,
                                        #mode="min",
                                        #restore_best_weights=True)
check = tf.keras.callbacks.ModelCheckpoint(filepath=mpath,
                                          save_best_only=True,
                                          verbose=1,
                                          mode="min",
                                          monitor="val_accuracy")

# %%
val_target = np_utils.to_categorical(val_target)
target_array = np_utils.to_categorical(target_array)

# %%
print(f"VALIDATE TARGET SHAPE: {val_target.shape}")
print(f"DATA TARGET SHAPE: {target_array.shape}")
# Out:
# VALIDATE TARGET SHAPE: (2000, 7)
# DATA TARGET SHAPE: (26709, 7)

# %% [markdown]
# # Model - Implementation of LeNet

# %%
shape = data_array[0].shape
print(f"SHAPE OF INPUT: {shape}")
# Out:
# SHAPE OF INPUT: (48, 48)

# %%
def conv_add(md:classmethod,filters:int,kernelsize:tuple)->PARAMETERS:
    md.add(Conv2D(filters=filters,
                 kernel_size=kernelsize,
                 padding="same",
                 activation="relu"))
    md.add(MaxPooling2D(pool_size=(2,2)))

# %%
def fully_connected(md:classmethod,ds:int,act:str)->PARAMETERS:
    md.add(Dense(units=ds,activation=act))

# %%
model = Sequential()
model.add(Conv2D(filters=32,
                 kernel_size=(5,5),
                 padding="same",
                 activation="relu",
                 input_shape=(48,48,1)))
conv_add(model,64,(2,2))
model.add(BatchNormalization())
conv_add(model,128,(2,2))
model.add(Dropout(0.25))
conv_add(model,256,(2,2))
model.add(Dropout(0.25))
model.add(Flatten())
fully_connected(model,84,"relu")
fully_connected(model,7,"softmax")

# %%
print("MODEL SUMMARY:\n\n")
print(model.summary())
# Out:
# MODEL SUMMARY:
#
#
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 48, 48, 32)        832
#
#  conv2d_13 (Conv2D)          (None, 48, 48, 64)        8256
#
#  max_pooling2d_9 (MaxPooling  (None, 24, 24, 64)       0
#  2D)
#
#  batch_normalization_3 (Batc  (None, 24, 24, 64)       256
#  hNormalization)
#
#  conv2d_14 (Conv2D)          (None, 24, 24, 128)       32896
#
#  max_pooling2d_10 (MaxPoolin  (None, 12, 12, 128)      0
#  g2D)
#
#  dropout_6 (Dropout)         (None, 12, 12, 128)       0
#
#  conv2d_15 (Conv2D)          (None, 12, 12, 256)       131328
#
#  max_pooling2d_11 (MaxPoolin  (None, 6, 6, 256)        0
#  g2D)
#
#  dropout_7 (Dropout)         (None, 6, 6, 256)         0
#
#  flatten_3 (Flatten)         (None, 9216)              0
#
#  dense_6 (Dense)             (None, 84)                774228
#
#  dense_7 (Dense)             (None, 7)                 595
#
# =================================================================
# Total params: 948,391
# Trainable params: 948,263
# Non-trainable params: 128
# _________________________________________________________________
# None

# %%
model.compile(optimizer=Adam(),
             loss="categorical_crossentropy",
             metrics=["accuracy"])

# %%
his = model.fit(data_array,
                target_array,
                epochs=30,
                callbacks=[check],
                validation_data=(val_data,val_target),
                batch_size=120)
# Out:
# Epoch 1/30
# 222/223 [============================>.] - ETA: 0s - loss: 1.7055 - accuracy: 0.3253
# Epoch 1: val_accuracy improved from inf to 0.32700, saving model to modelcheckpoint
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# 223/223 [==============================] - 12s 42ms/step - loss: 1.7053 - accuracy: 0.3254 - val_loss: 1.8551 - val_accuracy: 0.3270
# Epoch 2/30
# 223/223 [==============================] - ETA: 0s - loss: 1.4638 - accuracy: 0.4379
# Epoch 2: val_accuracy did not improve from 0.32700
# 223/223 [==============================] - 8s 34ms/step - loss: 1.4638 - accuracy: 0.4379 - val_loss: 1.6700 - val_accuracy: 0.4640
# Epoch 3/30
# 223/223 [==============================] - ETA: 0s - loss: 1.3452 - accuracy: 0.4857
# Epoch 3: val_accuracy did not improve from 0.32700
# 223/223 [==============================] - 7s 34ms/step - loss: 1.3452 - accuracy: 0.4857 - val_loss: 1.3770 - val_accuracy: 0.4985
# Epoch 4/30
# 223/223 [==============================] - ETA: 0s - loss: 1.2723 - accuracy: 0.5157
# Epoch 4: val_accuracy did not improve from 0.32700
# 223/223 [==============================] - 8s 34ms/step - loss: 1.2723 - accuracy: 0.5157 - val_loss: 1.2694 - val_accuracy: 0.5215
# Epoch 5/30
# 223/223 [==============================] - ETA: 0s - loss: 1.2205 - accuracy: 0.5359
# Epoch 5: val_accuracy did not improve from 0.32700
# 223/223 [==============================] - 8s 34ms/step - loss: 1.2205 - accuracy: 0.5359 - val_loss: 1.2319 - val_accuracy: 0.5205
# Epoch 6/30
# 223/223 [==============================] - ETA: 0s - loss: 1.1735 - accuracy: 0.5534
# Epoch 6: val_accuracy did not improve from 0.32700
# 223/223 [==============================] - 8s 34ms/step - loss: 1.1735 - accuracy: 0.5534 - val_loss: 1.2516 - val_accuracy: 0.5255
# Epoch 7/30
# 223/223 [==============================] - ETA: 0s - loss: 1.1366 - accuracy: 0.5706
# Epoch 7: val_accuracy did not improve from 0.32700
# 223/223 [==============================] - 8s 36ms/step - loss: 1.1366 - accuracy: 0.5706 - val_loss: 1.2031 - val_accuracy: 0.5495
# Epoch 8/30
# 222/223 [============================>.] - ETA: 0s - loss: 1.0977 - accuracy: 0.5843
# Epoch 8: val_accuracy did not improve from 0.32700
# 223/223 [==============================] - 8s 36ms/step - loss: 1.0973 - accuracy: 0.5846 - val_loss: 1.1799 - val_accuracy: 0.5490
# Epoch 9/30
# 223/223 [==============================] - ETA: 0s - loss: 1.0651 - accuracy: 0.5987
# Epoch 9: val_accuracy did not improve from 0.32700
# 223/223 [==============================] - 8s 34ms/step - loss: 1.0651 - accuracy: 0.5987 - val_loss: 1.1499 - val_accuracy: 0.5685
# Epoch 10/30
# 223/223 [==============================] - ETA: 0s - loss: 1.0326 - accuracy: 0.6133
# Epoch 10: val_accuracy did not improve from 0.32700
# 223/223 [==============================] - 8s 35ms/step - loss: 1.0326 - accuracy: 0.6133 - val_loss: 1.1879 - val_accuracy: 0.5525
# Epoch 11/30
# 222/223 [============================>.] - ETA: 0s - loss: 0.9971 - accuracy: 0.6253
# Epoch 11: val_accuracy did not improve from 0.32700
# 223/223 [==============================] - 8s 35ms/step - loss: 0.9967 - accuracy: 0.6255 - val_loss: 1.1518 - val_accuracy: 0.5680
# Epoch 12/30
# 223/223 [==============================] - ETA: 0s - loss: 0.9658 - accuracy: 0.6351
# Epoch 12: val_accuracy did not improve from 0.32700
# 223/223 [==============================] - 8s 35ms/step - loss: 0.9658 - accuracy: 0.6351 - val_loss: 1.1683 - val_accuracy: 0.5675
# Epoch 13/30
# 223/223 [==============================] - ETA: 0s - loss: 0.9359 - accuracy: 0.6477
# Epoch 13: val_accuracy did not improve from 0.32700
# 223/223 [==============================] - 8s 35ms/step - loss: 0.9359 - accuracy: 0.6477 - val_loss: 1.1431 - val_accuracy: 0.5685
# Epoch 14/30
# 223/223 [==============================] - ETA: 0s - loss: 0.9073 - accuracy: 0.6560
# Epoch 14: val_accuracy did not improve from 0.32700
# 223/223 [==============================] - 8s 35ms/step - loss: 0.9073 - accuracy: 0.6560 - val_loss: 1.1922 - val_accuracy: 0.5525
# Epoch 15/30
# 223/223 [==============================] - ETA: 0s - loss: 0.8905 - accuracy: 0.6637
# Epoch 15: val_accuracy did not improve from 0.32700
# 223/223 [==============================] - 8s 36ms/step - loss: 0.8905 - accuracy: 0.6637 - val_loss: 1.1953 - val_accuracy: 0.5580
# Epoch 16/30
# 223/223 [==============================] - ETA: 0s - loss: 0.8568 - accuracy: 0.6779
# Epoch 16: val_accuracy did not improve from 0.32700
# 223/223 [==============================] - 8s 34ms/step - loss: 0.8568 - accuracy: 0.6779 - val_loss: 1.1667 - val_accuracy: 0.5685
# Epoch 17/30
# 223/223 [==============================] - ETA: 0s - loss: 0.8213 - accuracy: 0.6954
# Epoch 17: val_accuracy did not improve from 0.32700
# 223/223 [==============================] - 8s 36ms/step - loss: 0.8213 - accuracy: 0.6954 - val_loss: 1.1870 - val_accuracy: 0.5595
# Epoch 18/30
# 223/223 [==============================] - ETA: 0s - loss: 0.7994 - accuracy: 0.7019
# Epoch 18: val_accuracy did not improve from 0.32700
# 223/223 [==============================] - 8s 35ms/step - loss: 0.7994 - accuracy: 0.7019 - val_loss: 1.1835 - val_accuracy: 0.5720
# Epoch 19/30
# 223/223 [==============================] - ETA: 0s - loss: 0.7759 - accuracy: 0.7085
# Epoch 19: val_accuracy did not improve from 0.32700
# 223/223 [==============================] - 8s 34ms/step - loss: 0.7759 - accuracy: 0.7085 - val_loss: 1.2365 - val_accuracy: 0.5475
# Epoch 20/30
# 223/223 [==============================] - ETA: 0s - loss: 0.7466 - accuracy: 0.7190
# Epoch 20: val_accuracy did not improve from 0.32700
# 223/223 [==============================] - 8s 35ms/step - loss: 0.7466 - accuracy: 0.7190 - val_loss: 1.2161 - val_accuracy: 0.5670
# Epoch 21/30
# 223/223 [==============================] - ETA: 0s - loss: 0.7269 - accuracy: 0.7289
# Epoch 21: val_accuracy did not improve from 0.32700
# 223/223 [==============================] - 8s 34ms/step - loss: 0.7269 - accuracy: 0.7289 - val_loss: 1.2055 - val_accuracy: 0.5750
# Epoch 22/30
# 223/223 [==============================] - ETA: 0s - loss: 0.7001 - accuracy: 0.7376
# Epoch 22: val_accuracy did not improve from 0.32700
# 223/223 [==============================] - 8s 35ms/step - loss: 0.7001 - accuracy: 0.7376 - val_loss: 1.2264 - val_accuracy: 0.5690
# Epoch 23/30
# 223/223 [==============================] - ETA: 0s - loss: 0.6805 - accuracy: 0.7431
# Epoch 23: val_accuracy did not improve from 0.32700
# 223/223 [==============================] - 8s 35ms/step - loss: 0.6805 - accuracy: 0.7431 - val_loss: 1.2325 - val_accuracy: 0.5710
# Epoch 24/30
# 223/223 [==============================] - ETA: 0s - loss: 0.6470 - accuracy: 0.7593
# Epoch 24: val_accuracy did not improve from 0.32700
# 223/223 [==============================] - 8s 34ms/step - loss: 0.6470 - accuracy: 0.7593 - val_loss: 1.2555 - val_accuracy: 0.5730
# Epoch 25/30
# 223/223 [==============================] - ETA: 0s - loss: 0.6249 - accuracy: 0.7678
# Epoch 25: val_accuracy did not improve from 0.32700
# 223/223 [==============================] - 8s 35ms/step - loss: 0.6249 - accuracy: 0.7678 - val_loss: 1.3655 - val_accuracy: 0.5660
# Epoch 26/30
# 223/223 [==============================] - ETA: 0s - loss: 0.6082 - accuracy: 0.7750
# Epoch 26: val_accuracy did not improve from 0.32700
# 223/223 [==============================] - 8s 35ms/step - loss: 0.6082 - accuracy: 0.7750 - val_loss: 1.2722 - val_accuracy: 0.5700
# Epoch 27/30
# 223/223 [==============================] - ETA: 0s - loss: 0.5953 - accuracy: 0.7788
# Epoch 27: val_accuracy did not improve from 0.32700
# 223/223 [==============================] - 8s 35ms/step - loss: 0.5953 - accuracy: 0.7788 - val_loss: 1.3238 - val_accuracy: 0.5630
# Epoch 28/30
# 223/223 [==============================] - ETA: 0s - loss: 0.5701 - accuracy: 0.7885
# Epoch 28: val_accuracy did not improve from 0.32700
# 223/223 [==============================] - 8s 35ms/step - loss: 0.5701 - accuracy: 0.7885 - val_loss: 1.3340 - val_accuracy: 0.5655
# Epoch 29/30
# 223/223 [==============================] - ETA: 0s - loss: 0.5491 - accuracy: 0.7948
# Epoch 29: val_accuracy did not improve from 0.32700
# 223/223 [==============================] - 8s 35ms/step - loss: 0.5491 - accuracy: 0.7948 - val_loss: 1.2925 - val_accuracy: 0.5805
# Epoch 30/30
# 223/223 [==============================] - ETA: 0s - loss: 0.5315 - accuracy: 0.8041
# Epoch 30: val_accuracy did not improve from 0.32700
# 223/223 [==============================] - 8s 35ms/step - loss: 0.5315 - accuracy: 0.8041 - val_loss: 1.3737 - val_accuracy: 0.5830

# %%
plt.style.use("dark_background")

# %%
history_data = pd.DataFrame(his.history)

# %%
plt.figure(figsize=(15,8))
history_data.plot()
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.plot(his.history["accuracy"],label="TRAINING ACCURACY",marker="o")
plt.plot(his.history["val_accuracy"],label="VALIDATION ACCURACY",marker="o")
plt.xlabel("EPOCH")
plt.ylabel("ACCURACY")
plt.title("ACCURACY CONTROL")
plt.legend()
plt.show()

# %%
model.save("testmodel.h5")

# %% [markdown]
# # Face Detection

# %%
dict_res = {0:"Angry",
           1:"Disgust",
           2:"Fear",
           3:"Happy",
           4:"Neutral",
           5:"Sad",
           6:"Surprise"}

# %%
pathface = "facedata"
if os.path.exists(pathface):
    pass
else:
    os.mkdir(pathface)

# %%
mpathface = "mainframedata"
if os.path.exists(mpathface):
    pass
else:
    os.mkdir(mpathface)

# %%
#shutil.rmtree(mpathface)
#shutil.rmtree(pathface)

# %%
# !kaggle datasets download -d gpreda/haar-cascades-for-face-detection
# Out:
# haar-cascades-for-face-detection.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
def face_ext(datavideo:str,tld:list,pld:list)->RESULTS:
    hd = cv.CascadeClassifier("/content/haarcascade_frontalface_default.xml")
    cap = cv.VideoCapture(datavideo)
    iface = 0
    while (cap.isOpened()):
        r,frm = cap.read()
        if r == True:
            iface += 1
            img = cv.cvtColor(frm,cv.COLOR_BGR2GRAY)
            face = hd.detectMultiScale(img,1.1,4)
            for (x,y,w,h) in face:
                ft = img[y:y+h,x:x+w]
                test_input = cv.resize(ft,(48,48))
                test_input = test_input.reshape(48,48,1)
                test_array = np.array(test_input)
                test_array = np.expand_dims(test_array,axis=0)
                predict_result = model.predict(test_array,verbose=0)
                target_result = list(predict_result[0])
                result_last = target_result.index(max(target_result))
                cv.rectangle(img,(x,y),(x+w,y+h),(0,0,255),2)
                cv.putText(img,
                           dict_res[int(result_last)],
                           (x+10,y),
                           cv.FONT_HERSHEY_SIMPLEX,
                           0.9,
                           (0, 0, 255),
                           2)
                tld.append(ft)
                pld.append(img)
                cv.imwrite(f"mainframedata/mainface_{iface}.jpg",img)
                cv.imwrite(f"facedata/face_{iface}.jpg",ft)
    print("[+] DONE")

# %%
tld = []
pld = []

# %%
#face_ext("/content/babies.mp4", tld,pld)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-297-2f85014402c1> in <cell line: 1>()
# ----> 1 face_ext("/content/babies.mp4", tld,pld)
#
# <ipython-input-294-896d1170f244> in face_ext(datavideo, tld, pld)
#       4     iface = 0
#       5     while (cap.isOpened()):
# ----> 6         r,frm = cap.read()
#       7         if r == True:
#       8             iface += 1
#
# KeyboardInterrupt:

# %%
if len(tld) > 0:
    plt.figure(figsize=(15, 8))
    plt.xlabel(f"SHAPE: {tld[0].shape}")
    plt.title("FACE")
    plt.imshow(tld[0])
    plt.tight_layout()
    plt.show()
else:
    print("No elements found in the face_list.")

# %%
test_input = cv.resize(tld[0],(48,48))
test_input = test_input.reshape(48,48,1)

# %%
plt.figure(figsize=(15,8))
plt.xlabel(f"SHAPE: {test_input.shape}")
plt.title("FACE")
plt.imshow(test_input)
plt.tight_layout()
plt.show()

# %%
test_array = np.array(test_input)
print(f"ARRAY SHAPE: {test_array.shape}")
# Out:
# ARRAY SHAPE: (48, 48, 1)

# %%
test_array = np.expand_dims(test_array,axis=0)
print(f"ARRAY EXPAND SHAPE: {test_array.shape}")
# Out:
# ARRAY EXPAND SHAPE: (1, 48, 48, 1)

# %%
predict_result = model.predict(test_array)
# Out:
# 1/1 [==============================] - 0s 33ms/step

# %%
print(f"PREDICTION RESULT: {predict_result[0]}")
# Out:
# PREDICTION RESULT: [6.5239861e-28 0.0000000e+00 0.0000000e+00 0.0000000e+00 6.2212677e-35
#  1.0000000e+00 1.3495968e-35]

# %%
target_result = list(predict_result[0])
print(f"TARGET RESULT: {target_result.index(max(target_result))}")
# Out:
# TARGET RESULT: 5

# %%
plt.figure(figsize=(15,8))
plt.xlabel(f"SHAPE: {test_input.shape}")
plt.title(f"FACE - FEAR: {target_result.index(max(target_result))}")
plt.imshow(test_input)
plt.tight_layout()
plt.show()

# %%
def displaying_all(source):
    figure = plt.figure(figsize=(10,10))
    Image_List = []
    plt.style.use("dark_background")
    for indexing in source:
        Read_IMG = plt.imshow(indexing, animated=True,cmap="hot")
        plt.axis('off')
        Image_List.append([Read_IMG])
    Animation_Func = animation.ArtistAnimation(figure,
                                               Image_List,
                                               interval=120,
                                               repeat_delay=9000)
    plt.close()
    return Animation_Func

# %%
HTML(displaying_all(pld).to_html5_video())
# Out:
# <video width="1000" height="1000" controls autoplay loop>
#   <source type="video/mp4" src="...
